# %% [markdown]
# # Unit 5 - Financial Planning

# %%
# Initial imports
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from MCForecastTools import MCSimulation

# %matplotlib inline

# %%
# Load .env enviroment variables
load_dotenv()
# Out:
# True

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# %%
# Create the Alpaca API object
alpaca = tradeapi.REST(alpaca_api_key, alpaca_secret_key, api_version="v2")

# %% [markdown]
# ## Part 1 - Personal Finance Planner

# %% [markdown]
# ### Collect Crypto Prices Using the `requests` Library

# %%
my_btc = 1.2
my_eth = 5.3

# %%
# Crypto API Request URLs
btc_url = "https://api.alternative.me/v2/ticker/Bitcoin/?convert=CAD"
eth_url = "https://api.alternative.me/v2/ticker/Ethereum/?convert=CAD"

# %%
btc_response = requests.get(btc_url).json()

# %%
btc_response
# Out:
# {'data': {'1': {'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'website_slug': 'bitcoin',
#    'rank': 1,
#    'circulating_supply': 18700706,
#    'total_supply': 18700706,
#    'max_supply': 21000000,
#    'quotes': {'USD': {'price': 56861.0,
#      'volume_24h': 69561667942,
#      'market_cap': 1069208985669,
#      'percentage_change_1h': -0.618639791163057,
#      'percentage_change_24h': 5.02296083054103,
#      'percentage_change_7d': 3.3981405900569,
#      'percent_change_1h': -0.618639791163057,
#      'percent_change_24h': 5.02296083054103,
#      'percent_change_7d': 3.3981405900569}},
#    'last_updated': 1620246901}},
#  'metadata': {'timestamp': 1620246901,
#   'num_cryptocurrencies': 1306,
#   'error': None}}

# %%
btc_price = btc_response['data']['1']['quotes']['USD']['price']
btc_price
# Out:
# 56861.0

# %%
eth_response = requests.get(eth_url).json()

# %%
eth_response
# Out:
# {'data': {'1027': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'website_slug': 'ethereum',
#    'rank': 2,
#    'circulating_supply': 115753106,
#    'total_supply': 115753106,
#    'max_supply': 0,
#    'quotes': {'USD': {'price': 3454.84,
#      'volume_24h': 62568782025,
#      'market_cap': 401835032483,
#      'percentage_change_1h': -0.0380232186624342,
#      'percentage_change_24h': 2.31229894276724,
#      'percentage_change_7d': 30.5111048985773,
#      'percent_change_1h': -0.0380232186624342,
#      'percent_change_24h': 2.31229894276724,
#      'percent_change_7d': 30.5111048985773},
#     'CAD': {'price': 4241.852552,
#      'volume_24h': 76821950570.295,
#      'market_cap': 493373052882.628,
#      'percent_change_1h': -0.0380232186624342,
#      'percent_change_24h': 2.31229894276724,
#      'percent_change_7d': 30.5111048985773}},
#    'last_updated': 1620246833}},
#  'metadata': {'timestamp': 1620246833,
#   'num_cryptocurrencies': 1306,
# ...

# %%
eth_price = eth_response['data']['1027']['quotes']['USD']['price']
eth_price
# Out:
# 3454.84

# %%
my_btc_value = my_btc * btc_price
my_eth_value = my_eth * eth_price

# Print current crypto wallet balance
print(f"The current value of your {my_btc} BTC is ${my_btc_value:0.2f}")
print(f"The current value of your {my_eth} ETH is ${my_eth_value:0.2f}")
# Out:
# The current value of your 1.2 BTC is $68233.20
# The current value of your 5.3 ETH is $18310.65

# %% [markdown]
# ### Collect Investments Data Using Alpaca: `SPY` (stocks) and `AGG` (bonds)

# %%
# Current amount of shares
my_agg = 200
my_spy = 50

# %%
# Format current date as ISO format
today = pd.Timestamp("2021-05-01", tz="America/New_York").isoformat()

# Set the tickers
tickers = ["AGG", "SPY"]

# Set timeframe to '1D' for Alpaca API
timeframe = "1D"

# Get current closing prices for SPY and AGG
df_shares = alpaca.get_barset(
   tickers,
    timeframe,
    start = today,
    limit = 1000
).df

# Preview DataFrame
df_shares.head()
# Out:
#                               AGG                                       \
#                              open    high       low     close   volume
# time
# 2021-05-03 00:00:00-04:00  114.40  114.59  114.3300  114.4000  5537985
# 2021-05-04 00:00:00-04:00  114.55  114.70  114.4100  114.5285  4679145
# 2021-05-05 00:00:00-04:00  114.45  114.62  114.4222  114.6100  3861137
#
#                               SPY
#                              open    high      low   close    volume
# time
# 2021-05-03 00:00:00-04:00  419.43  419.84  417.665  418.18  60956273
# 2021-05-04 00:00:00-04:00  416.08  416.60  411.670  415.64  88481725
# 2021-05-05 00:00:00-04:00  417.38  417.63  414.940  415.72  51327353

# %%
# Pick AGG and SPY close prices
agg_close_price = df_shares['AGG']['close'][0]
spy_close_price = df_shares['SPY']['close'][0]
# Print AGG and SPY close prices
print(f"Current AGG closing price: ${agg_close_price}")
print(f"Current SPY closing price: ${spy_close_price}")
# Out:
# Current AGG closing price: $114.4
# Current SPY closing price: $418.18

# %%
# Compute the current value of shares
my_spy_value = my_spy * spy_close_price
my_agg_value = my_agg * agg_close_price
# Print current value of share
print(f"The current value of your {my_spy} SPY shares is ${my_spy_value:0.2f}")
print(f"The current value of your {my_agg} AGG shares is ${my_agg_value:0.2f}")
# Out:
# The current value of your 50 SPY shares is $20909.00
# The current value of your 200 AGG shares is $22880.00

# %% [markdown]
# ### Savings Health Analysis

# %%
# Set monthly household income
monthly_income = 12000

# Create savings DataFrame
savings_data = [my_btc_value + my_eth_value, my_spy_value + my_agg_value]
df_savings = pd.DataFrame(savings_data, columns=["amount"], index=['crypto','shares'])

# Display savings DataFrame
display(df_savings)
# Out:
#            amount
# crypto  86543.852
# shares  43789.000

# %%
# Plot savings pie chart
df_savings.plot.pie(y='amount', title="Composition of Personal Savings")
# Out:
# <AxesSubplot:title={'center':'Composition of Personal Savings'}, ylabel='amount'>

# %%
# Set ideal emergency fund
emergency_fund = monthly_income * 3

# Calculate total amount of savings
total_savings = float(df_savings.sum())
total_savings

# Validate savings health
if (total_savings > emergency_fund):
    print("Congratulations, you have sufficient money in your savings")
elif (total_savings == emergency_fund):
    print("Congratulations you have reached your savings financial goal")
else:
   print(f"The current value of your savings is ${(emergency_fund - total_savings):0.2f} below your emergency fund goal")
# Out:
# Congratulations you have sufficient money in your savings

# %% [markdown]
# ## Part 2 - Retirement Planning
#
# ### Monte Carlo Simulation

# %%
# Set start and end dates of five years back from today.
start_date = pd.Timestamp('2016-05-03', tz='America/New_York').isoformat()
end_date = pd.Timestamp('2021-05-03', tz='America/New_York').isoformat()

# %%
# Get 5 years' worth of historical data for SPY and AGG
historical_5yr_data = alpaca.get_barset(
    tickers,
    timeframe,
    start=start_date,
    end=end_date,
    limit=1000,
).df

# Display sample data
historical_5yr_data.head()
# Out:
#                               AGG                                         \
#                              open     high       low    close     volume
# time
# 2017-05-11 00:00:00-04:00  108.35  108.540  108.3435  108.515  1773499.0
# 2017-05-12 00:00:00-04:00  108.81  108.940  108.7800  108.920  1136553.0
# 2017-05-15 00:00:00-04:00  108.85  108.940  108.8200  108.890  1620264.0
# 2017-05-16 00:00:00-04:00  108.88  109.101  108.8800  109.000  1394153.0
# 2017-05-17 00:00:00-04:00  109.35  109.600  109.2800  109.560  2263851.0
#
#                               SPY
#                              open    high     low    close       volume
# time
# 2017-05-11 00:00:00-04:00     NaN     NaN     NaN      NaN          NaN
# 2017-05-12 00:00:00-04:00  239.09  239.21  238.67  239.030   35283567.0
# 2017-05-15 00:00:00-04:00  239.47  240.44  239.45  240.245   42230620.0
# 2017-05-16 00:00:00-04:00  240.62  240.67  239.63  240.100   37206183.0
# ...

# %%
# Configuring a Monte Carlo simulation to forecast 30 years cumulative returns
# Set number of simulations
num_sims = 500

# Input data for Monte Carlo simulation to forecast thirty years daily returns
MC_30_dist = MCSimulation(
    portfolio_data = historical_5yr_data,
    weights = [.4,.6],
    num_simulation = num_sims,
    num_trading_days = 252*30
)

# %%
# Printing the simulation input data
MC_30_dist.portfolio_data.head()
# Out:
#                               AGG                                         \
#                              open     high       low    close     volume
# time
# 2017-05-11 00:00:00-04:00  108.35  108.540  108.3435  108.515  1773499.0
# 2017-05-12 00:00:00-04:00  108.81  108.940  108.7800  108.920  1136553.0
# 2017-05-15 00:00:00-04:00  108.85  108.940  108.8200  108.890  1620264.0
# 2017-05-16 00:00:00-04:00  108.88  109.101  108.8800  109.000  1394153.0
# 2017-05-17 00:00:00-04:00  109.35  109.600  109.2800  109.560  2263851.0
#
#                                            SPY                           \
#                           daily_return    open    high     low    close
# time
# 2017-05-11 00:00:00-04:00          NaN     NaN     NaN     NaN      NaN
# 2017-05-12 00:00:00-04:00     0.003732  239.09  239.21  238.67  239.030
# 2017-05-15 00:00:00-04:00    -0.000275  239.47  240.44  239.45  240.245
# 2017-05-16 00:00:00-04:00     0.001010  240.62  240.67  239.63  240.100
# ...

# %%
# Running a Monte Carlo simulation to forecast 30 years cumulative returns
MC_30_dist.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
# Plot simulation outcomes
line_plot = MC_30_dist.plot_simulation()

# %%
# Plot probability distribution and confidence intervals
dist_plot = MC_30_dist.plot_distribution()

# %% [markdown]
# ### Retirement Analysis

# %%
# Fetch summary statistics from the Monte Carlo simulation results
MC_30_tbl = MC_30_dist.summarize_cumulative_return()

# Print summary statistics
MC_30_tbl
# Out:
# count           500.000000
# mean             22.655934
# std              17.245855
# min               2.125130
# 25%              11.074768
# 50%              17.479277
# 75%              29.101770
# max             112.818344
# 95% CI Lower      4.265207
# 95% CI Upper     67.863482
# Name: 7560, dtype: float64

# %% [markdown]
# ### Calculate the expected portfolio return at the 95% lower and upper confidence intervals based on a `$20,000` initial investment.

# %%
# Set initial investment
initial_investment = 20000

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $20,000
ci_30_lower = round(MC_30_tbl[8]*initial_investment,2)
ci_30_upper = round(MC_30_tbl[9]*initial_investment,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 30 years will end within the range of"
      f" ${ci_30_lower} and ${ci_30_upper}")
# Out:
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 30 years will end within the range of $85304.14 and $1357269.65

# %% [markdown]
# ### Calculate the expected portfolio return at the `95%` lower and upper confidence intervals based on a `50%` increase in the initial investment.

# %%
# Set initial investment
initial_investment = 20000 * 1.5

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $30,000
ci_30_lower = round(MC_30_tbl[8]*initial_investment,2)
ci_30_upper = round(MC_30_tbl[9]*initial_investment,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 30 years will end within in the range of"
      f" ${ci_30_lower} and ${ci_30_upper}")
# Out:
# There is a 95% chance that an initial investment of $30000.0 in the portfolio over the next 30 years will end within in the range of $127956.21 and $2035904.47

# %% [markdown]
# ## Optional Challenge - Early Retirement
#
#
# ### Five Years Retirement Option

# %%
# Configuring a Monte Carlo simulation to forecast 5 years cumulative returns
num_sims = 500

# Input data for Monte Carlo simulation to forecast thirty years daily returns
MC_5_dist = MCSimulation(
    portfolio_data = historical_5yr_data,
    weights = [.4,.6],
    num_simulation = num_sims,
    num_trading_days = 252*5)

# %%
# Running a Monte Carlo simulation to forecast 5 years cumulative returns
MC_5_dist.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
# Plot simulation outcomes
line_plot = MC_5_dist.plot_simulation()

# %%
# Plot probability distribution and confidence intervals
dist_plot = MC_5_dist.plot_distribution()

# %%
# Fetch summary statistics from the Monte Carlo simulation results
MC_5_tbl = MC_5_dist.summarize_cumulative_return()

# Print summary statistics
MC_5_tbl
# Out:
# count           500.000000
# mean              1.735129
# std               0.475828
# min               0.792079
# 25%               1.392280
# 50%               1.656663
# 75%               1.988246
# max               3.543347
# 95% CI Lower      0.985937
# 95% CI Upper      2.893714
# Name: 1260, dtype: float64

# %%
# Set initial investment
initial_investment = 20000

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $20,000
ci_5_lower = round(MC_5_tbl[8]*initial_investment,2)
ci_5_upper = round(MC_5_tbl[9]*initial_investment,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${ci_5_lower} and ${ci_5_upper}")
# Out:
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 5 years will end within in the range of $19718.75 and $57874.29

# %% [markdown]
# ### Ten Years Retirement Option

# %%
# Configuring a Monte Carlo simulation to forecast 10 years cumulative returns
num_sims = 500

# Input data for Monte Carlo simulation to forecast thirty years daily returns
MC_10_dist = MCSimulation(
    portfolio_data = historical_5yr_data,
    weights = [.4,.6],
    num_simulation = num_sims,
    num_trading_days = 252*10)

# %%
# Running a Monte Carlo simulation to forecast 10 years cumulative returns
MC_10_dist.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
# Plot simulation outcomes
line_plot = MC_10_dist.plot_simulation()

# %%
# Plot probability distribution and confidence intervals
dist_plot = MC_10_dist.plot_distribution()

# %%
# Fetch summary statistics from the Monte Carlo simulation results
MC_10_tbl = MC_10_dist.summarize_cumulative_return()

# Print summary statistics
MC_10_tbl
# Out:
# count           500.000000
# mean              2.803246
# std               1.151761
# min               0.806044
# 25%               2.006215
# 50%               2.581842
# 75%               3.374072
# max               8.353787
# 95% CI Lower      1.213304
# 95% CI Upper      5.525305
# Name: 2520, dtype: float64

# %%
# Set initial investment
initial_investment = 20000

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $20,000
ci_10_lower = round(MC_10_tbl[8]*initial_investment,2)
ci_10_upper = round(MC_10_tbl[9]*initial_investment,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 10 years will end within in the range of"
      f" ${ci_10_lower} and ${ci_10_upper}")
# Out:
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 10 years will end within in the range of $24266.08 and $110506.1

# %%
# Change the weights of the portfolio to be 60% Bonds and 40% Shares (Option10b) over a 10 year period
#Configuring a Monte Carlo simulation to forecast 10 years cumulative returns
# Set number of simulations
num_sims = 500

# Input data for Monte Carlo simulation to forecast 10 years daily returns
MC_10b_dist = MCSimulation(
    portfolio_data = historical_5yr_data,
    weights = [.6,.4],
    num_simulation = num_sims,
    num_trading_days = 252*10)

# %%
MC_10b_dist.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# ...

# %%
# Plot probability distribution and confidence intervals
dist_plot = MC_10b_dist.plot_distribution()

# %%
# Fetch summary statistics from the Monte Carlo simulation results
MC_10b_tbl = MC_10b_dist.summarize_cumulative_return()

# Print summary statistics
MC_10b_tbl
# Out:
# count           500.000000
# mean              2.092999
# std               0.607587
# min               0.897606
# 25%               1.660090
# 50%               1.998440
# 75%               2.425888
# max               5.076146
# 95% CI Lower      1.191858
# 95% CI Upper      3.582180
# Name: 2520, dtype: float64

# %%
# Set initial investment
initial_investment = 20000

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $20,000
ci_10b_lower = round(MC_10b_tbl[8]*initial_investment,2)
ci_10b_upper = round(MC_10b_tbl[9]*initial_investment,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 10 years will end within in the range of"
      f" ${ci_10b_lower} and ${ci_10b_upper}")
# Out:
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 10 years will end within in the range of $23837.16 and $71643.6

# %%
# Comparing a 60:40 split between shares and Bonds for retiremnet in 10 years, there is a greater likelihood of obtaining better returns by investing in a
# higher % of shares in the portfolio as these have a potentially higher upside return than Bonds over a 10 year period. The low side returns are similar.
# Overall, retirement in the next 5-10 years will not result ina good lifestyle.
